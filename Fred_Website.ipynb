# %%
# !pip install fredapi

import pandas as pd
import numpy as np
import matplotlib as plt
import plotly.express as px

from fredapi import Fred

# %%
fred = Fred(api_key='a5df3b65123347c0b6895867998783c1')

sp_search=fred.search('S&P',order_by='popularity')
sp_search
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2024-03-19   2024-03-19
# CSUSHPINSA              CSUSHPINSA     2024-03-19   2024-03-19
# SP500                        SP500     2024-03-19   2024-03-19
# MEHOINUSA672N        MEHOINUSA672N     2024-03-19   2024-03-19
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2024-03-19   2024-03-19
# ...                            ...            ...          ...
# DDDI12SMA156NWDB  DDDI12SMA156NWDB     2024-03-19   2024-03-19
# DDDI01GTA156NWDB  DDDI01GTA156NWDB     2024-03-19   2024-03-19
# Q03069USQ605NNBR  Q03069USQ605NNBR     2024-03-19   2024-03-19
# CSHXCPVEA156NRUG  CSHXCPVEA156NRUG     2024-03-19   2024-03-19
# CSHMCPNPA156NRUG  CSHMCPNPA156NRUG     2024-03-19   2024-03-19
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# ...

# %%
#Pull raw Data 
sp500 = fred.get_series(series_id='SP500')

# %%
sp500.plot(figsize=(10,6),title= 'SP500',lw=2)
# Out:
# <Axes: title={'center': 'SP500'}>

# %%
fred.search('Unemployement rate',order_by='popularity')
Unemployment_rate=fred.get_series(series_id='UNRATE')
Unemployment_rate.plot(figsize=(11,10),title='Unemployment_Rate',lw=2)
# Out:
# <Axes: title={'center': 'Unemployment_Rate'}>

# %%
fred.search('APR',order_by='popularity')
# Out:
#                                   id realtime_start realtime_end  \
# series id
# SOFRINDEX                  SOFRINDEX     2024-03-19   2024-03-19
# PPIFES                        PPIFES     2024-03-19   2024-03-19
# WPU3911                      WPU3911     2024-03-19   2024-03-19
# PPICOR                        PPICOR     2024-03-19   2024-03-19
# PCU2381MR2381MR      PCU2381MR2381MR     2024-03-19   2024-03-19
# ...                              ...            ...          ...
# WPU312101                  WPU312101     2024-03-19   2024-03-19
# WPS312                        WPS312     2024-03-19   2024-03-19
# WPU30160201              WPU30160201     2024-03-19   2024-03-19
# PCU313210313210FA  PCU313210313210FA     2024-03-19   2024-03-19
# PCU336214336214M    PCU336214336214M     2024-03-19   2024-03-19
#
#                                                                title  \
# series id
# SOFRINDEX                                                 SOFR Index
# ...

# %%
fred.search ('AMAZON PRICE')
df_amazon=fred.get_series
